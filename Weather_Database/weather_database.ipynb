# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np

# Import API key

from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
import citipy

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=679950f7cd1949499bc40385b03d4123

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name    
    if city not in cities:
        cities.append(city)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 1 | fortuna
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | cidreira
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | quatre cocos
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | shingu
# Processing Record 17 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | ayagoz
# Processing Record 22 of Set 1 | temple
# Processing Record 23 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | roanoke rapids
# Processing Record 27 of Set 1 | hearst
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | kirakira
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | leningradskiy
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | banepa
# Processing Record 37 of Set 1 | naze
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | moindou
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | klaksvik
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | airai
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | dumai
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | ous
# Processing Record 4 of Set 2 | egvekinot
# Processing Record 5 of Set 2 | lichinga
# Processing Record 6 of Set 2 | les cayes
# Processing Record 7 of Set 2 | key west
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | la ronge
# Processing Record 12 of Set 2 | tilichiki
# Processing Record 13 of Set 2 | oktyabrskiy
# Processing Record 14 of Set 2 | kristiansund
# Processing Record 15 of Set 2 | nishihara
# Processing Record 16 of Set 2 | cayenne
# Processing Record 17 of Set 2 | svetlogorsk
# Processing Record 18 of Set 2 | vao
# Processing Record 19 of Set 2 | katsuura
# Processing Record 20 of Set 2 | tuatapere
# Processing Record 21 of Set 2 | kaeo
# Processing Record 22 of Set 2 | udachnyy
# Processing Record 23 of Set 2 | komsomolskiy
# Processing Record 24 of Set 2 | gasa
# Processing Record 25 of Set 2 | zhanaozen
# Processing Record 26 of Set 2 | kawalu
# Processing Record 27 of Set 2 | narsaq
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | college
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | arenzano
# Processing Record 34 of Set 2 | lagoa
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | east london
# Processing Record 37 of Set 2 | sao filipe
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | ejea de los caballeros
# Processing Record 41 of Set 2 | soyo
# Processing Record 42 of Set 2 | sarankhola
# Processing Record 43 of Set 2 | silyanah
# City not found. Skipping...
# Processing Record 44 of Set 2 | brasschaat
# Processing Record 45 of Set 2 | lebedinyy
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | caxito
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | faya
# Processing Record 2 of Set 3 | lere
# Processing Record 3 of Set 3 | nioki
# Processing Record 4 of Set 3 | jiangyou
# Processing Record 5 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 3 | baracoa
# Processing Record 7 of Set 3 | nisia floresta
# Processing Record 8 of Set 3 | flin flon
# Processing Record 9 of Set 3 | bakel
# Processing Record 10 of Set 3 | shenkursk
# Processing Record 11 of Set 3 | pangody
# Processing Record 12 of Set 3 | priargunsk
# Processing Record 13 of Set 3 | namibe
# Processing Record 14 of Set 3 | saint-pierre
# Processing Record 15 of Set 3 | valparaiso
# Processing Record 16 of Set 3 | ostrovnoy
# Processing Record 17 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 18 of Set 3 | salacgriva
# Processing Record 19 of Set 3 | colac
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | puerto ayora
# Processing Record 22 of Set 3 | yaan
# Processing Record 23 of Set 3 | george town
# Processing Record 24 of Set 3 | lasa
# Processing Record 25 of Set 3 | sakakah
# Processing Record 26 of Set 3 | kosonsoy
# Processing Record 27 of Set 3 | port lincoln
# Processing Record 28 of Set 3 | haverfordwest
# Processing Record 29 of Set 3 | mount isa
# Processing Record 30 of Set 3 | arlit
# Processing Record 31 of Set 3 | mezen
# Processing Record 32 of Set 3 | mabaruma
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | belaya gora
# Processing Record 35 of Set 3 | cah ab
# City not found. Skipping...
# Processing Record 36 of Set 3 | klyuchi
# Processing Record 37 of Set 3 | ouallam
# Processing Record 38 of Set 3 | acarau
# Processing Record 39 of Set 3 | dongzhen
# Processing Record 40 of Set 3 | singleton
# Processing Record 41 of Set 3 | los llanos de aridane
# Processing Record 42 of Set 3 | kisaran
# Processing Record 43 of Set 3 | obo
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | windsor
# Processing Record 46 of Set 3 | itarema
# Processing Record 47 of Set 3 | nyurba
# Processing Record 48 of Set 3 | jacareacanga
# Processing Record 49 of Set 3 | carnarvon
# Processing Record 50 of Set 3 | erenhot
# Processing Record 1 of Set 4 | loukhi
# Processing Record 2 of Set 4 | astoria
# Processing Record 3 of Set 4 | peruc
# Processing Record 4 of Set 4 | olinda
# Processing Record 5 of Set 4 | the valley
# Processing Record 6 of Set 4 | khatanga
# Processing Record 7 of Set 4 | saskylakh
# Processing Record 8 of Set 4 | jablah
# Processing Record 9 of Set 4 | gao
# Processing Record 10 of Set 4 | kodiak
# Processing Record 11 of Set 4 | phan thiet
# Processing Record 12 of Set 4 | usinsk
# Processing Record 13 of Set 4 | taylorville
# Processing Record 14 of Set 4 | port macquarie
# Processing Record 15 of Set 4 | tomatlan
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | narrabri
# Processing Record 18 of Set 4 | mersing
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | tubarao
# Processing Record 21 of Set 4 | kahului
# Processing Record 22 of Set 4 | shitkino
# Processing Record 23 of Set 4 | bengkalis
# City not found. Skipping...
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | bambous virieux
# Processing Record 26 of Set 4 | isangel
# Processing Record 27 of Set 4 | teguise
# Processing Record 28 of Set 4 | trincomalee
# Processing Record 29 of Set 4 | lima
# Processing Record 30 of Set 4 | liwale
# Processing Record 31 of Set 4 | alta floresta
# Processing Record 32 of Set 4 | sioux lookout
# Processing Record 33 of Set 4 | kenai
# Processing Record 34 of Set 4 | ambon
# Processing Record 35 of Set 4 | alvorada
# Processing Record 36 of Set 4 | fairbanks
# Processing Record 37 of Set 4 | yumen
# Processing Record 38 of Set 4 | bengkulu
# Processing Record 39 of Set 4 | tyup
# Processing Record 40 of Set 4 | huangnihe
# Processing Record 41 of Set 4 | vostok
# Processing Record 42 of Set 4 | praia da vitoria
# Processing Record 43 of Set 4 | shchelyayur
# City not found. Skipping...
# Processing Record 44 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 4 | biak
# Processing Record 46 of Set 4 | hermanus
# Processing Record 47 of Set 4 | juxian
# City not found. Skipping...
# Processing Record 48 of Set 4 | castiglion fiorentino
# Processing Record 49 of Set 4 | las choapas
# Processing Record 50 of Set 4 | chau doc
# Processing Record 1 of Set 5 | kutum
# Processing Record 2 of Set 5 | kaniama
# Processing Record 3 of Set 5 | grants pass
# Processing Record 4 of Set 5 | maldonado
# Processing Record 5 of Set 5 | palmer
# Processing Record 6 of Set 5 | salinas
# Processing Record 7 of Set 5 | ler
# Processing Record 8 of Set 5 | borzya
# Processing Record 9 of Set 5 | fare
# Processing Record 10 of Set 5 | severo-kurilsk
# Processing Record 11 of Set 5 | micheweni
# Processing Record 12 of Set 5 | rio grande
# Processing Record 13 of Set 5 | batemans bay
# Processing Record 14 of Set 5 | chilca
# Processing Record 15 of Set 5 | mount gambier
# Processing Record 16 of Set 5 | lompoc
# Processing Record 17 of Set 5 | alofi
# Processing Record 18 of Set 5 | nome
# Processing Record 19 of Set 5 | yulara
# Processing Record 20 of Set 5 | pisco
# Processing Record 21 of Set 5 | ilulissat
# Processing Record 22 of Set 5 | prainha
# Processing Record 23 of Set 5 | shakhrinau
# City not found. Skipping...
# Processing Record 24 of Set 5 | muisne
# Processing Record 25 of Set 5 | guaraniacu
# Processing Record 26 of Set 5 | rurrenabaque
# Processing Record 27 of Set 5 | medea
# Processing Record 28 of Set 5 | iracoubo
# Processing Record 29 of Set 5 | antipino
# Processing Record 30 of Set 5 | marawi
# Processing Record 31 of Set 5 | pevek
# Processing Record 32 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 33 of Set 5 | hamilton
# Processing Record 34 of Set 5 | shasta lake
# Processing Record 35 of Set 5 | krasnyy chikoy
# Processing Record 36 of Set 5 | palmeira das missoes
# Processing Record 37 of Set 5 | thompson
# Processing Record 38 of Set 5 | beyneu
# Processing Record 39 of Set 5 | kupang
# Processing Record 40 of Set 5 | keuruu
# Processing Record 41 of Set 5 | ambilobe
# Processing Record 42 of Set 5 | gat
# Processing Record 43 of Set 5 | bandarbeyla
# Processing Record 44 of Set 5 | wulanhaote
# City not found. Skipping...
# Processing Record 45 of Set 5 | moree
# Processing Record 46 of Set 5 | ahipara
# Processing Record 47 of Set 5 | nanortalik
# Processing Record 48 of Set 5 | francavilla al mare
# Processing Record 49 of Set 5 | socorro
# Processing Record 50 of Set 5 | pishin
# Processing Record 1 of Set 6 | port hedland
# Processing Record 2 of Set 6 | deputatskiy
# Processing Record 3 of Set 6 | svetlaya
# Processing Record 4 of Set 6 | san andres
# Processing Record 5 of Set 6 | ribeira grande
# Processing Record 6 of Set 6 | quebo
# Processing Record 7 of Set 6 | teplodar
# Processing Record 8 of Set 6 | santa maria do para
# Processing Record 9 of Set 6 | birjand
# Processing Record 10 of Set 6 | zhezkazgan
# Processing Record 11 of Set 6 | seredka
# Processing Record 12 of Set 6 | prince rupert
# Processing Record 13 of Set 6 | ondjiva
# Processing Record 14 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 6 | moba
# Processing Record 16 of Set 6 | byron bay
# Processing Record 17 of Set 6 | clyde river
# Processing Record 18 of Set 6 | kavieng
# Processing Record 19 of Set 6 | jiuquan
# Processing Record 20 of Set 6 | cordele
# Processing Record 21 of Set 6 | san patricio
# Processing Record 22 of Set 6 | leh
# Processing Record 23 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 24 of Set 6 | la union
# Processing Record 25 of Set 6 | ngaoundere
# Processing Record 26 of Set 6 | meulaboh
# Processing Record 27 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 6 | cooma
# Processing Record 29 of Set 6 | suntar
# Processing Record 30 of Set 6 | amazar
# Processing Record 31 of Set 6 | constitucion
# Processing Record 32 of Set 6 | uusikaupunki
# Processing Record 33 of Set 6 | mitu
# Processing Record 34 of Set 6 | ust-kut
# Processing Record 35 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 6 | kaitangata
# Processing Record 37 of Set 6 | iowa city
# Processing Record 38 of Set 6 | vardo
# Processing Record 39 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 6 | charlottetown
# Processing Record 41 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 6 | tateyama
# Processing Record 43 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 44 of Set 6 | capul
# Processing Record 45 of Set 6 | hit
# Processing Record 46 of Set 6 | luderitz
# Processing Record 47 of Set 6 | chumikan
# Processing Record 48 of Set 6 | sahrak
# City not found. Skipping...
# Processing Record 49 of Set 6 | macaubas
# Processing Record 50 of Set 6 | riyadh
# Processing Record 1 of Set 7 | denpasar
# Processing Record 2 of Set 7 | chifeng
# Processing Record 3 of Set 7 | shetpe
# Processing Record 4 of Set 7 | billings
# Processing Record 5 of Set 7 | margate
# Processing Record 6 of Set 7 | ardesen
# Processing Record 7 of Set 7 | flinders
# Processing Record 8 of Set 7 | laguna
# Processing Record 9 of Set 7 | castro verde
# Processing Record 10 of Set 7 | hirara
# Processing Record 11 of Set 7 | lincoln
# Processing Record 12 of Set 7 | santa barbara
# Processing Record 13 of Set 7 | boa vista
# Processing Record 14 of Set 7 | lavrentiya
# Processing Record 15 of Set 7 | waipawa
# Processing Record 16 of Set 7 | glace bay
# Processing Record 17 of Set 7 | winneba
# Processing Record 18 of Set 7 | vesyegonsk
# Processing Record 19 of Set 7 | tonj
# Processing Record 20 of Set 7 | kemijarvi
# Processing Record 21 of Set 7 | ilek
# Processing Record 22 of Set 7 | zelenogorskiy
# Processing Record 23 of Set 7 | christchurch
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | maumere
# Processing Record 26 of Set 7 | eydhafushi
# Processing Record 27 of Set 7 | zunyi
# Processing Record 28 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 7 | bairiki
# Processing Record 30 of Set 7 | yarega
# Processing Record 31 of Set 7 | sulecin
# Processing Record 32 of Set 7 | tikapur
# Processing Record 33 of Set 7 | harper
# Processing Record 34 of Set 7 | linhares
# Processing Record 35 of Set 7 | jambi
# Processing Record 36 of Set 7 | verkhniy avzyan
# Processing Record 37 of Set 7 | malaya serdoba
# Processing Record 38 of Set 7 | sorland
# Processing Record 39 of Set 7 | san mateo ixtatan
# Processing Record 40 of Set 7 | sopelana
# Processing Record 41 of Set 7 | port elizabeth
# Processing Record 42 of Set 7 | kachug
# Processing Record 43 of Set 7 | acapulco
# Processing Record 44 of Set 7 | ko samui
# Processing Record 45 of Set 7 | islamabad
# Processing Record 46 of Set 7 | san cristobal
# Processing Record 47 of Set 7 | jiujiang
# Processing Record 48 of Set 7 | saint-leu
# Processing Record 49 of Set 7 | vestmannaeyjar
# Processing Record 50 of Set 7 | saint george
# Processing Record 1 of Set 8 | navabad
# City not found. Skipping...
# Processing Record 2 of Set 8 | kargasok
# Processing Record 3 of Set 8 | aban
# Processing Record 4 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 8 | bereda
# Processing Record 6 of Set 8 | havre-saint-pierre
# Processing Record 7 of Set 8 | mitsamiouli
# Processing Record 8 of Set 8 | kushima
# Processing Record 9 of Set 8 | ishigaki
# Processing Record 10 of Set 8 | mogok
# Processing Record 11 of Set 8 | marsabit
# Processing Record 12 of Set 8 | la seyne-sur-mer
# Processing Record 13 of Set 8 | baragua
# Processing Record 14 of Set 8 | hay river
# Processing Record 15 of Set 8 | upernavik
# Processing Record 16 of Set 8 | ankazoabo
# Processing Record 17 of Set 8 | staryy nadym
# Processing Record 18 of Set 8 | huarmey
# Processing Record 19 of Set 8 | henties bay
# Processing Record 20 of Set 8 | bago
# Processing Record 21 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 8 | labuan
# Processing Record 23 of Set 8 | coroico
# Processing Record 24 of Set 8 | beira
# Processing Record 25 of Set 8 | hasaki
# Processing Record 26 of Set 8 | eirunepe
# Processing Record 27 of Set 8 | villa vazquez
# City not found. Skipping...
# Processing Record 28 of Set 8 | wyndham
# Processing Record 29 of Set 8 | ancud
# Processing Record 30 of Set 8 | grand-santi
# Processing Record 31 of Set 8 | sur
# Processing Record 32 of Set 8 | labuhan
# Processing Record 33 of Set 8 | provideniya
# Processing Record 34 of Set 8 | malanje
# Processing Record 35 of Set 8 | fernley
# Processing Record 36 of Set 8 | beloha
# Processing Record 37 of Set 8 | san vicente de chucuri
# Processing Record 38 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 8 | sawakin
# Processing Record 40 of Set 8 | kavaratti
# Processing Record 41 of Set 8 | norman wells
# Processing Record 42 of Set 8 | royan
# Processing Record 43 of Set 8 | camopi
# Processing Record 44 of Set 8 | puerto del rosario
# Processing Record 45 of Set 8 | warrington
# Processing Record 46 of Set 8 | okato
# Processing Record 47 of Set 8 | hofn
# Processing Record 48 of Set 8 | lodwar
# Processing Record 49 of Set 8 | tommot
# Processing Record 50 of Set 8 | kattivakkam
# Processing Record 1 of Set 9 | tiruvottiyur
# City not found. Skipping...
# Processing Record 2 of Set 9 | olafsvik
# Processing Record 3 of Set 9 | bandar-e lengeh
# Processing Record 4 of Set 9 | manzhouli
# Processing Record 5 of Set 9 | beni mazar
# Processing Record 6 of Set 9 | coutances
# Processing Record 7 of Set 9 | talbahat
# Processing Record 8 of Set 9 | manono
# Processing Record 9 of Set 9 | koulamoutou
# Processing Record 10 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 9 | mandan
# Processing Record 12 of Set 9 | angoche
# Processing Record 13 of Set 9 | smithers
# Processing Record 14 of Set 9 | shamary
# Processing Record 15 of Set 9 | lubao
# Processing Record 16 of Set 9 | ulaanbaatar
# Processing Record 17 of Set 9 | pachino
# Processing Record 18 of Set 9 | kieta
# Processing Record 19 of Set 9 | pedasi
# Processing Record 20 of Set 9 | bien hoa
# Processing Record 21 of Set 9 | cedar city
# Processing Record 22 of Set 9 | saint-augustin
# Processing Record 23 of Set 9 | goya
# Processing Record 24 of Set 9 | hambantota
# Processing Record 25 of Set 9 | pyaozerskiy
# Processing Record 26 of Set 9 | mao
# Processing Record 27 of Set 9 | envira
# Processing Record 28 of Set 9 | waddan
# Processing Record 29 of Set 9 | coihaique
# Processing Record 30 of Set 9 | half moon bay
# Processing Record 31 of Set 9 | davila
# Processing Record 32 of Set 9 | chapada dos guimaraes
# Processing Record 33 of Set 9 | el alto
# Processing Record 34 of Set 9 | westport
# Processing Record 35 of Set 9 | evensk
# Processing Record 36 of Set 9 | comodoro rivadavia
# Processing Record 37 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 9 | zhigansk
# Processing Record 39 of Set 9 | champerico
# Processing Record 40 of Set 9 | sao joao da barra
# Processing Record 41 of Set 9 | talara
# Processing Record 42 of Set 9 | mujiayingzi
# Processing Record 43 of Set 9 | plettenberg bay
# Processing Record 44 of Set 9 | bilibino
# Processing Record 45 of Set 9 | ciudad bolivar
# Processing Record 46 of Set 9 | chicxulub
# Processing Record 47 of Set 9 | karasuk
# Processing Record 48 of Set 9 | mabay
# Processing Record 49 of Set 9 | atar
# Processing Record 50 of Set 9 | isla vista
# Processing Record 1 of Set 10 | gold coast
# Processing Record 2 of Set 10 | mnogovershinnyy
# Processing Record 3 of Set 10 | deori
# Processing Record 4 of Set 10 | wellsford
# Processing Record 5 of Set 10 | dzhida
# Processing Record 6 of Set 10 | grand gaube
# Processing Record 7 of Set 10 | aksarka
# Processing Record 8 of Set 10 | hami
# Processing Record 9 of Set 10 | salekhard
# Processing Record 10 of Set 10 | monrovia
# Processing Record 11 of Set 10 | ust-maya
# Processing Record 12 of Set 10 | qingdao
# Processing Record 13 of Set 10 | narbonne
# Processing Record 14 of Set 10 | ambulu
# Processing Record 15 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 16 of Set 10 | arman
# Processing Record 17 of Set 10 | nola
# Processing Record 18 of Set 10 | ranong
# Processing Record 19 of Set 10 | loubomo
# Processing Record 20 of Set 10 | dudinka
# Processing Record 21 of Set 10 | puerto escondido
# Processing Record 22 of Set 10 | iqaluit
# Processing Record 23 of Set 10 | nanning
# Processing Record 24 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 10 | kathmandu
# Processing Record 26 of Set 10 | aksay
# Processing Record 27 of Set 10 | fort nelson
# Processing Record 28 of Set 10 | honiara
# Processing Record 29 of Set 10 | miami beach
# Processing Record 30 of Set 10 | san pietro vernotico
# Processing Record 31 of Set 10 | kabalo
# Processing Record 32 of Set 10 | faanui
# Processing Record 33 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 34 of Set 10 | nalut
# Processing Record 35 of Set 10 | karratha
# Processing Record 36 of Set 10 | preston
# Processing Record 37 of Set 10 | kamenka
# Processing Record 38 of Set 10 | vallenar
# Processing Record 39 of Set 10 | vila franca do campo
# Processing Record 40 of Set 10 | archidona
# Processing Record 41 of Set 10 | san ignacio
# Processing Record 42 of Set 10 | najran
# Processing Record 43 of Set 10 | amreli
# Processing Record 44 of Set 10 | trat
# Processing Record 45 of Set 10 | hervey bay
# Processing Record 46 of Set 10 | qui nhon
# Processing Record 47 of Set 10 | nouadhibou
# Processing Record 48 of Set 10 | asau
# Processing Record 49 of Set 10 | port shepstone
# Processing Record 50 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 11 | zapadnaya dvina
# Processing Record 3 of Set 11 | kingaroy
# Processing Record 4 of Set 11 | tezu
# Processing Record 5 of Set 11 | samarai
# Processing Record 6 of Set 11 | cap malheureux
# Processing Record 7 of Set 11 | nabire
# Processing Record 8 of Set 11 | sandy bay
# Processing Record 9 of Set 11 | longyearbyen
# Processing Record 10 of Set 11 | san jose
# Processing Record 11 of Set 11 | morros
# Processing Record 12 of Set 11 | ferrol
# Processing Record 13 of Set 11 | saravan
# Processing Record 14 of Set 11 | dakar
# Processing Record 15 of Set 11 | tautira
# Processing Record 16 of Set 11 | vyshkov
# Processing Record 17 of Set 11 | katima mulilo
# Processing Record 18 of Set 11 | kandrian
# Processing Record 19 of Set 11 | mayo
# Processing Record 20 of Set 11 | beaverlodge
# Processing Record 21 of Set 11 | bakchar
# Processing Record 22 of Set 11 | jumla
# Processing Record 23 of Set 11 | inuvik
# Processing Record 24 of Set 11 | birao
# Processing Record 25 of Set 11 | kailua
# Processing Record 26 of Set 11 | urumqi
# Processing Record 27 of Set 11 | rio gallegos
# Processing Record 28 of Set 11 | abha
# Processing Record 29 of Set 11 | husavik
# Processing Record 30 of Set 11 | nago
# Processing Record 31 of Set 11 | shenjiamen
# Processing Record 32 of Set 11 | ponta do sol
# Processing Record 33 of Set 11 | paso de los toros
# Processing Record 34 of Set 11 | erice
# Processing Record 35 of Set 11 | talnakh
# Processing Record 36 of Set 11 | mehamn
# Processing Record 37 of Set 11 | deogarh
# Processing Record 38 of Set 11 | ndele
# Processing Record 39 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 11 | ola
# Processing Record 41 of Set 11 | dezhou
# Processing Record 42 of Set 11 | mayumba
# Processing Record 43 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 44 of Set 11 | andapa
# Processing Record 45 of Set 11 | anderson
# Processing Record 46 of Set 11 | cockburn town
# Processing Record 47 of Set 11 | tiarei
# Processing Record 48 of Set 11 | coquimbo
# Processing Record 49 of Set 11 | kruisfontein
# Processing Record 50 of Set 11 | ternate
# Processing Record 1 of Set 12 | vanino
# Processing Record 2 of Set 12 | qasigiannguit
# Processing Record 3 of Set 12 | aklavik
# Processing Record 4 of Set 12 | luan
# Processing Record 5 of Set 12 | touros
# Processing Record 6 of Set 12 | gradignan
# Processing Record 7 of Set 12 | san rafael
# Processing Record 8 of Set 12 | haines junction
# Processing Record 9 of Set 12 | talaya
# Processing Record 10 of Set 12 | dayong
# Processing Record 11 of Set 12 | lebowakgomo
# Processing Record 12 of Set 12 | santa isabel do rio negro
# Processing Record 13 of Set 12 | saalfelden
# City not found. Skipping...
# Processing Record 14 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 12 | tupik
# Processing Record 16 of Set 12 | lodja
# Processing Record 17 of Set 12 | tahe
# Processing Record 18 of Set 12 | sechura
# Processing Record 19 of Set 12 | olga
# Processing Record 20 of Set 12 | bandar
# Processing Record 21 of Set 12 | turtas
# Processing Record 22 of Set 12 | huilong
# Processing Record 23 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 12 | swan hill
# Processing Record 25 of Set 12 | paamiut
# Processing Record 26 of Set 12 | port-cartier
# Processing Record 27 of Set 12 | brae
# Processing Record 28 of Set 12 | villa union
# Processing Record 29 of Set 12 | perth
# Processing Record 30 of Set 12 | salisbury
# Processing Record 31 of Set 12 | uchiza
# Processing Record 32 of Set 12 | thinadhoo
# Processing Record 33 of Set 12 | tawau
# Processing Record 34 of Set 12 | kilindoni
# Processing Record 35 of Set 12 | pokhara
# Processing Record 36 of Set 12 | waitati
# Processing Record 37 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 38 of Set 12 | qinhuangdao
# Processing Record 39 of Set 12 | praia
# Processing Record 40 of Set 12 | iwanai
# Processing Record 41 of Set 12 | bangalore
# Processing Record 42 of Set 12 | nador
# Processing Record 43 of Set 12 | monastyrshchina
# Processing Record 44 of Set 12 | korla
# Processing Record 45 of Set 12 | lakes entrance
# Processing Record 46 of Set 12 | kars
# Processing Record 47 of Set 12 | filingue
# Processing Record 48 of Set 12 | port augusta
# Processing Record 49 of Set 12 | wairoa
# Processing Record 50 of Set 12 | dongsheng
# Processing Record 1 of Set 13 | rawson
# Processing Record 2 of Set 13 | maceio
# Processing Record 3 of Set 13 | caravelas
# Processing Record 4 of Set 13 | terrace
# Processing Record 5 of Set 13 | farafangana
# Processing Record 6 of Set 13 | tunceli
# Processing Record 7 of Set 13 | rocha
# Processing Record 8 of Set 13 | aguimes
# Processing Record 9 of Set 13 | cuiluan
# Processing Record 10 of Set 13 | abu zabad
# Processing Record 11 of Set 13 | shitanjing
# Processing Record 12 of Set 13 | khandyga
# Processing Record 13 of Set 13 | novoagansk
# Processing Record 14 of Set 13 | marzuq
# Processing Record 15 of Set 13 | jonuta
# Processing Record 16 of Set 13 | bosaso
# Processing Record 17 of Set 13 | yuanping
# Processing Record 18 of Set 13 | mamedkala
# Processing Record 19 of Set 13 | yoichi
# Processing Record 20 of Set 13 | lang suan
# Processing Record 21 of Set 13 | okhotsk
# Processing Record 22 of Set 13 | awbari
# Processing Record 23 of Set 13 | rincon
# Processing Record 24 of Set 13 | wajid
# Processing Record 25 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 26 of Set 13 | severo-yeniseyskiy
# Processing Record 27 of Set 13 | emerald
# Processing Record 28 of Set 13 | itajuba
# Processing Record 29 of Set 13 | kibaya
# Processing Record 30 of Set 13 | shakawe
# Processing Record 31 of Set 13 | paranga
# Processing Record 32 of Set 13 | dingli
# Processing Record 33 of Set 13 | lake city
# Processing Record 34 of Set 13 | kollam
# Processing Record 35 of Set 13 | adana
# Processing Record 36 of Set 13 | taungdwingyi
# Processing Record 37 of Set 13 | antalaha
# Processing Record 38 of Set 13 | padang
# Processing Record 39 of Set 13 | burica
# City not found. Skipping...
# Processing Record 40 of Set 13 | osorio
# Processing Record 41 of Set 13 | palasa
# Processing Record 42 of Set 13 | svobodnyy
# Processing Record 43 of Set 13 | beruwala
# Processing Record 44 of Set 13 | san francisco
# Processing Record 45 of Set 13 | daru
# Processing Record 46 of Set 13 | port keats
# Processing Record 47 of Set 13 | coahuayana
# Processing Record 48 of Set 13 | ca mau
# Processing Record 49 of Set 13 | lubango
# Processing Record 50 of Set 13 | manavalakurichi
# Processing Record 1 of Set 14 | sheridan
# Processing Record 2 of Set 14 | alice springs
# Processing Record 3 of Set 14 | chimbote
# Processing Record 4 of Set 14 | leninsk
# Processing Record 5 of Set 14 | buluang
# Processing Record 6 of Set 14 | coihueco
# Processing Record 7 of Set 14 | gazanjyk
# Processing Record 8 of Set 14 | thohoyandou
# Processing Record 9 of Set 14 | buala
# Processing Record 10 of Set 14 | julio de castilhos
# Processing Record 11 of Set 14 | muros
# Processing Record 12 of Set 14 | sisimiut
# Processing Record 13 of Set 14 | roald
# Processing Record 14 of Set 14 | kismayo
# Processing Record 15 of Set 14 | jining
# Processing Record 16 of Set 14 | poya
# Processing Record 17 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 18 of Set 14 | patterson
# Processing Record 19 of Set 14 | price
# Processing Record 20 of Set 14 | bagalkot
# Processing Record 21 of Set 14 | pitimbu
# Processing Record 22 of Set 14 | albion
# Processing Record 23 of Set 14 | geraldton
# Processing Record 24 of Set 14 | deming
# Processing Record 25 of Set 14 | mocuba
# Processing Record 26 of Set 14 | lukovetskiy
# Processing Record 27 of Set 14 | pontianak
# Processing Record 28 of Set 14 | kyaikto
# Processing Record 29 of Set 14 | high level
# Processing Record 30 of Set 14 | belmonte
# Processing Record 31 of Set 14 | balad
# Processing Record 32 of Set 14 | siklos
# Processing Record 33 of Set 14 | kaduqli
# Processing Record 34 of Set 14 | raga
# Processing Record 35 of Set 14 | lundamo
# Processing Record 36 of Set 14 | belen
# Processing Record 37 of Set 14 | anadyr
# Processing Record 38 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 39 of Set 14 | gorele
# Processing Record 40 of Set 14 | amapa
# Processing Record 41 of Set 14 | vestmanna
# Processing Record 42 of Set 14 | dindori
# Processing Record 43 of Set 14 | campina grande do sul
# Processing Record 44 of Set 14 | krasnovishersk
# Processing Record 45 of Set 14 | karlstad
# Processing Record 46 of Set 14 | te anau
# Processing Record 47 of Set 14 | serov
# Processing Record 48 of Set 14 | kijang
# Processing Record 49 of Set 14 | bembereke
# Processing Record 50 of Set 14 | ende
# Processing Record 1 of Set 15 | jieshou
# Processing Record 2 of Set 15 | mogochin
# City not found. Skipping...
# Processing Record 3 of Set 15 | palauig
# Processing Record 4 of Set 15 | altay
# Processing Record 5 of Set 15 | copiapo
# Processing Record 6 of Set 15 | lacolle
# Processing Record 7 of Set 15 | hazorasp
# Processing Record 8 of Set 15 | abu samrah
# Processing Record 9 of Set 15 | saint-francois
# Processing Record 10 of Set 15 | shanghai
# Processing Record 11 of Set 15 | ukiah
# Processing Record 12 of Set 15 | souillac
# Processing Record 13 of Set 15 | ponta delgada
# Processing Record 14 of Set 15 | isperih
# Processing Record 15 of Set 15 | tessalit
# Processing Record 16 of Set 15 | baoqing
# Processing Record 17 of Set 15 | ust-ishim
# Processing Record 18 of Set 15 | codrington
# Processing Record 19 of Set 15 | saint-joseph
# Processing Record 20 of Set 15 | ossora
# Processing Record 21 of Set 15 | chapais
# Processing Record 22 of Set 15 | lagoa da canoa
# Processing Record 23 of Set 15 | bac lieu
# Processing Record 24 of Set 15 | chakwal
# Processing Record 25 of Set 15 | ponoka
# Processing Record 26 of Set 15 | fene
# Processing Record 27 of Set 15 | cadillac
# Processing Record 28 of Set 15 | oistins
# Processing Record 29 of Set 15 | ignacio zaragoza
# Processing Record 30 of Set 15 | berlevag
# Processing Record 31 of Set 15 | medvezhyegorsk
# Processing Record 32 of Set 15 | magalia
# Processing Record 33 of Set 15 | sarkand
# Processing Record 34 of Set 15 | pingdingshan
# Processing Record 35 of Set 15 | panama city
# Processing Record 36 of Set 15 | dekoa
# City not found. Skipping...
# Processing Record 37 of Set 15 | marmaris
# Processing Record 38 of Set 15 | sundsvall
# Processing Record 39 of Set 15 | encruzilhada
# Processing Record 40 of Set 15 | mount hagen
# Processing Record 41 of Set 15 | hobe sound
# Processing Record 42 of Set 15 | bitung
# Processing Record 43 of Set 15 | diego de almagro
# Processing Record 44 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 15 | cabo rojo
# Processing Record 46 of Set 15 | jalu
# Processing Record 47 of Set 15 | port hardy
# Processing Record 48 of Set 15 | ballina
# Processing Record 49 of Set 15 | eureka
# Processing Record 50 of Set 15 | coolum beach
# Processing Record 1 of Set 16 | hobyo
# Processing Record 2 of Set 16 | broken hill
# Processing Record 3 of Set 16 | swift current
# Processing Record 4 of Set 16 | penzance
# Processing Record 5 of Set 16 | dzerzhinskoye
# Processing Record 6 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 16 | broome
# Processing Record 8 of Set 16 | senno
# Processing Record 9 of Set 16 | dzhusaly
# City not found. Skipping...
# Processing Record 10 of Set 16 | shimoni
# Processing Record 11 of Set 16 | saint anthony
# Processing Record 12 of Set 16 | muana
# Processing Record 13 of Set 16 | richards bay
# Processing Record 14 of Set 16 | tura
# Processing Record 15 of Set 16 | ahome
# Processing Record 16 of Set 16 | naryan-mar
# Processing Record 17 of Set 16 | pangnirtung
# Processing Record 18 of Set 16 | baghdad
# Processing Record 19 of Set 16 | hornepayne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(20)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Barrow  71.2906 -156.7887     33.40        99         100
# 1          Ushuaia -54.8000  -68.3000     46.02        65          75
# 2          Fortuna  40.5982 -124.1573     73.92        70           0
# 3        Esperance -33.8667  121.9000     57.16        81           1
# 4         Cidreira -30.1811  -50.2056     65.25        93         100
# 5             Lebu -37.6167  -73.6500     52.43        78           0
# 6            Tiksi  71.6872  128.8694     51.60        91          91
# 7            Bluff -46.6000  168.3333     47.80        75         100
# 8          Rikitea -23.1203 -134.9692     73.45        73          91
# 9     Quatre Cocos -20.2078   57.7625     68.11        76           5
# 10       Jamestown  42.0970  -79.2353     82.02        40          20
# 11         Qaanaaq  77.4840  -69.3632     41.22        68          11
# 12          Castro -24.7911  -50.0119     68.83        54         100
# 13          Shingu  33.7333  135.9833     76.17        92          68
# 14       Hithadhoo  -0.6000   73.0833     82.18        74         100
# 15       Busselton -33.6500  115.3333     59.81        83         100
# 16          Ayagoz  47.9714   80.4392     72.54        33           5
# 17          Temple  31.0982  -97.3428    101.23        36          20
# 18  Roanoke Rapids  36.4615  -77.6542     93.15        74           0
# 19          Hearst  49.6835  -83.6665     66.45        81          99
#
#     Wind Speed Country Current Description
# 0        12.33      US          light snow
# 1        21.85      AR       broken clouds
# 2        12.66      US           clear sky
# 3        12.37      AU           clear sky
# 4         9.95      BR       moderate rain
# 5        14.45      CL           clear sky
# 6         5.28      RU     overcast clouds
# 7        11.74      NZ     overcast clouds
# 8        21.36      PF     overcast clouds
# 9        11.27      MU           clear sky
# 10       14.97      US          few clouds
# 11        2.95      GL          few clouds
# 12        8.08      BR     overcast clouds
# 13        4.68      JP       broken clouds
# 14       11.72      MV     overcast clouds
# 15       18.52      AU     overcast clouds
# 16        8.93      KZ           clear sky
# 17       13.80      US          few clouds
# 18        8.05      US           clear sky
# 19        6.71      CA     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow      US  71.2906 -156.7887     33.40        99         100
# 1       Ushuaia      AR -54.8000  -68.3000     46.02        65          75
# 2       Fortuna      US  40.5982 -124.1573     73.92        70           0
# 3     Esperance      AU -33.8667  121.9000     57.16        81           1
# 4      Cidreira      BR -30.1811  -50.2056     65.25        93         100
# 5          Lebu      CL -37.6167  -73.6500     52.43        78           0
# 6         Tiksi      RU  71.6872  128.8694     51.60        91          91
# 7         Bluff      NZ -46.6000  168.3333     47.80        75         100
# 8       Rikitea      PF -23.1203 -134.9692     73.45        73          91
# 9  Quatre Cocos      MU -20.2078   57.7625     68.11        76           5
#
#    Wind Speed Current Description
# 0       12.33          light snow
# 1       21.85       broken clouds
# 2       12.66           clear sky
# 3       12.37           clear sky
# 4        9.95       moderate rain
# 5       14.45           clear sky
# 6        5.28     overcast clouds
# 7       11.74     overcast clouds
# 8       21.36     overcast clouds
# 9       11.27           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Databse.csv"
# Export the City_Data into a CSV.# Extract relevant fields from the DataFrame for plotting.
city_data_df.to_csv(output_data_file, index_label="City_ID")
